-- %%
create or replace table workspace.dimensions.dim_site as 
select 1 as SITE_ID, 'Site A' as SITE_NAME/*, '-27.4152317'::DOUBLE as LATITUDE, '153.058853'::DOUBLE as LONGITUDE*/, 30625130000 as MB_CODE_2021
union all
select 2, 'Site B', 30625130001
union all
select 3, 'Site C', 30625130002
union all
select 4, 'Site D', 30625130003
union all
select 5, 'Site E', 30625130004
union all
select 6, 'Site F', 30625130005
union all
select 7, 'Site G', 30625130006
union all
select 8, 'Site H', 30625130007
union all
select 9, 'Site I', 30625130008
union all
select 10, 'Site J', 30625130009
