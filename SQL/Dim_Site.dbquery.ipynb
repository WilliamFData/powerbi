-- %%
create or replace table workspace.dimension.dim_site as 
select 1 as SITE_ID, 'Site A' as SITE_NAME, '-27.4698'::DOUBLE as LATITUDE, '153.0251'::DOUBLE as LONGITUDE, 30565640000 as MB_CODE_2021, 'Brisbane City QLD 4000' as ADDRESS
union all
select 2, 'Site B', '-28.0167', '153.4000', 30276820000, 'Gold Coast QLD 4210'
union all
select 3, 'Site C', '-16.9186', '145.7781', 30189990000, 'Cairns City QLD 4870'
union all
select 4, 'Site D', '-19.2590', '146.8169', 30541520000, 'Townsville City QLD 4810'
union all
select 5, 'Site E', '-27.5598', '151.9507', 30526903000, 'Toowoomba City QLD 4350'
union all
select 6, 'Site F', '-23.3791', '150.5100', 30505782000, 'Rockhampton QLD 4700'
union all
select 7, 'Site G', '-20.7256', '139.4927', 30442947000, 'Mount Isa QLD 4825'
union all
select 8, 'Site H', '-23.4397', '144.2507', 30397990000, 'Longreach QLD 4730'
union all
select 9, 'Site I', '-25.2882', '152.8749', 30563603600, 'Urraween QLD 4655'
union all
select 10, 'Site J', '-15.4667', '145.2500', 30224680000, 'Cooktown QLD 4895'
