-- %%
create or replace table workspace.dimensions.dim_product as 
select 1 as PRODUCT_ID, 'Gadget X' as PRODUCT_NAME
  union all 
select 2, 'Gadget Y'
  union all 
select  3, 'Gadget Z'
  union all 
select 4, 'Widget A'
  union all 
select 5, 'Widget B'
  union all 
select 6, 'Widget C'
